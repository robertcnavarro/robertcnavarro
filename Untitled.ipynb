# %%
#installar packages
import re
import pandas as pd
import pandas_profiling
import numpy as np
import seaborn as sns
import numpy as np
import catboost
from catboost import CatBoostClassifier
import phik
from phik import resources, report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score
from catboost import CatBoostClassifier
#https://www.datacamp.com/community/tutorials/decision-tree-classification-python
#https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
#https://www.datacamp.com/community/tutorials/random-forests-classifier-python?utm_source=adwords_ppc&utm_medium=cpc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=&utm_network=g&utm_adpostion=&utm_creative=278443377086&utm_targetid=aud-299261629574:dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=1001765&gclid=Cj0KCQiAu62QBhC7ARIsALXijXTgLcXo7tj8eRaMiTw76g-_f7Kq5ZFURGBx3i3VOL3Vnuy8RR6dduUaAlMwEALw_wcB
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier
#Create a Gaussian Classifier
#clf=RandomForestClassifier(n_estimators=100)
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
#https://www.analyticsvidhya.com/blog/2021/01/a-quick-introduction-to-k-nearest-neighbor-knn-classification-using-python/
import tensorflow as tf
#Encoding Categorical Variable Gender
from sklearn.preprocessing import LabelEncoder
#Encoding Categorical variable Geography
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation
#from pandas.compat import StringIO

sns.set(style="whitegrid")

# %%
df2 = pd.read_excel(r'/home/lbcb/Downloads/BASE DE DATOS PARA TALLER 12.xlsx', sheet_name='Hoja1')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37365 entries, 0 to 37364
# Data columns (total 52 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   þÿNÚMERO CERTIFICADO                           37365 non-null  int64
#  1   DEPARTAMENTO                                   37365 non-null  object
#  2   MUNICIPIO                                      37365 non-null  object
#  3   AREA NACIMIENTO                                37365 non-null  object
#  4   INSPECCION CORREGIMIENTO O CASERIO NACIMIENTO  0 non-null      float64
#  5   SITIO NACIMIENTO                               37365 non-null  object
#  6   SEXO                                           37365 non-null  object
#  7   PESO (Gramos)                                  37365 non-null  int64
#  8   TALLA (Centímetros)                            37365 non-null  int64
# ...

# %%
df2_1=df2.drop(['þÿNÚMERO CERTIFICADO','DEPARTAMENTO','MUNICIPIO','AREA NACIMIENTO','INSPECCION CORREGIMIENTO O CASERIO NACIMIENTO','EDAD PADRE','NIVEL EDUCATIVO PADRE','ULTIMO AÑO APROBADO PADRE','FECHA EXPEDICIÓN','ESTADO CERTIFICADO','ÚLTIMA FECHA MODIFICACIÓN','FECHA REGISTRO','FECHA ANTERIOR HIJO NACIDO VIVO'], axis=1)

# %%
df2_1['TIPO PARTO'].unique()
# Out:
# array(['1', '2', '3', 'IGNORADO'], dtype=object)

# %%
df2_1['TIPO PARTO']=np.where(df2_1['TIPO PARTO'] =='IGNORADO', '4',df2_1['TIPO PARTO'])

# %%
df2_1['TIPO PARTO']=="2"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37360    False
# 37361    False
# 37362    False
# 37363    False
# 37364    False
# Name: TIPO PARTO, Length: 37365, dtype: bool

# %%
df4.head(1)
# Out:
#    þÿNÚMERO CERTIFICADO  DEPARTAMENTO     MUNICIPIO     AREA NACIMIENTO  \
# 0             158016348  BOGOTÁ, D.C.  BOGOTÁ, D.C.  CABECERA MUNICIPAL
#
#    INSPECCION CORREGIMIENTO O CASERIO NACIMIENTO      SITIO NACIMIENTO  \
# 0                                            NaN  INSTITUCIÓN DE SALUD
#
#        SEXO  PESO (Gramos)  TALLA (Centímetros) FECHA NACIMIENTO  ...  \
# 0  FEMENINO           1890                   44       2020-01-01  ...
#
#         NIVEL EDUCATIVO PADRE ULTIMO AÑO APROBADO PADRE  \
# 0  MEDIA ACADÉMICA O CLÁSICA                       11.0
#
#    TIPO DOCUMENTO CERTIFICADOR  PROFESIÓN CERTIFICADOR  \
# 0         CÉDULA DE CIUDADANÍA                  MÉDICO
#
#   DEPARTAMENTO EXPEDICIÓN MUNICIPIO EXPEDICIÓN  FECHA EXPEDICIÓN  \
# 0            BOGOTÁ, D.C.         BOGOTÁ, D.C.       '02/01/2020
#
#    ESTADO CERTIFICADO ÚLTIMA FECHA MODIFICACIÓN FECHA REGISTRO
# 0          CONFIRMADO                2020-02-14    '02/01/2020
#
# [1 rows x 52 columns]

# %%
df3=df4.describe(include='all')
# Out:
# <ipython-input-21-b19946ca6d41>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df3=df4.describe(include='all')

# %%
df3.to_excel(r'/media/lbcb/Roberton/elkin /articulo_ tuberculosis /new_Calculs/imagenens/dflinda.xlsx')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['SEXO']))
ax = sns.countplot(x=df4['SEXO'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['MULTIPLICIDAD EMBARAZO']))
ax = sns.countplot(x=df4['MULTIPLICIDAD EMBARAZO'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['APGAR1']))
ax = sns.countplot(x=df4['APGAR1'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['PARTO ATENDIDO POR']))
ax = sns.countplot(x=df4['PARTO ATENDIDO POR'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['TIEMPO DE GESTACIÓN']))
ax = sns.countplot(x=df4['TIEMPO DE GESTACIÓN'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()
GRUPO SANGUINEO

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['GRUPO SANGUINEO']))
ax = sns.countplot(x=df4['GRUPO SANGUINEO'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['PERTENENCIA ÉTNICA']))
ax = sns.countplot(x=df4['PERTENENCIA ÉTNICA'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['ESTADO CONYUGAL MADRE']))
ax = sns.countplot(x=df4['ESTADO CONYUGAL MADRE'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
     
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['NIVEL EDUCATIVO MADRE']))
ax = sns.countplot(x=df4['NIVEL EDUCATIVO MADRE'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
       
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = 11,8
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams['savefig.transparent'] = True
total = float(len(df4['ULTIMO AÑO APROBADO MADRE']))
ax = sns.countplot(x=df4['ULTIMO AÑO APROBADO MADRE'], palette="Set3")
plt.tight_layout()
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage,(x, y),ha='center')
plt.show()

# %%
from scipy.stats import chi2_contingency 
import matplotlib.pyplot as plt

# %%
df2_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37365 entries, 0 to 37364
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   SITIO NACIMIENTO             37365 non-null  object
#  1   SEXO                         37365 non-null  object
#  2   PESO (Gramos)                37365 non-null  int64
#  3   TALLA (Centímetros)          37365 non-null  int64
#  4   FECHA NACIMIENTO             37365 non-null  datetime64[ns]
#  5   HORA NACIMIENTO              37365 non-null  object
#  6   PARTO ATENDIDO POR           37365 non-null  object
#  7   TIEMPO DE GESTACIÓN          37362 non-null  float64
#  8   NÚMERO CONSULTAS PRENATALES  37360 non-null  float64
#  9   TIPO PARTO                   37365 non-null  float64
#  10  MULTIPLICIDAD EMBARAZO       37365 non-null  object
#  11  APGAR1                       37290 non-null  float64
# ...

# %%
df2_1['TIPO PARTO'] = df2_1['TIPO PARTO'].astype(float, errors = 'raise')

# %%
plt.figure(figsize=(16, 6))
#https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e
# define the mask to set the values in the upper triangle to True
mask1 = np.triu(np.ones_like(df2_1.corr(method='kendall'), dtype=np.bool))
heatmap1 = sns.heatmap(df2_1.corr(method='kendall'), mask=mask1, vmin=-1, vmax=1, annot=True, cmap='BrBG')
#heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# Out:
# <ipython-input-45-a11885945a3e>:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask1 = np.triu(np.ones_like(df2_1.corr(method='kendall'), dtype=np.bool))
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  <a list of 11 Text major ticklabel objects>)

# %%
plt.figure(figsize=(16, 6))
#https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e
# define the mask to set the values in the upper triangle to True
mask1 = np.triu(np.ones_like(df2_1.corr(method='kendall'), dtype=np.bool))
heatmap1 = sns.heatmap(df2_1.corr(method='kendall'), mask=mask1, vmin=-1, vmax=1, annot=True, cmap='BrBG')
#heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# %%
import statsmodels.api as sm
from scipy import stats

# %%
df2_1[["TALLA (Centímetros)","PESO (Gramos)"]]
# Out:
#        TALLA (Centímetros)  PESO (Gramos)
# 0                       44           1890
# 1                       53           3690
# 2                       52           3760
# 3                       50           2720
# 4                       50           3080
# ...                    ...            ...
# 37360                   49           2955
# 37361                   53           3415
# 37362                   49           2680
# 37363                   48           2965
# 37364                   48           2830
#
# [37365 rows x 2 columns]

# %%
k2, p = stats.normaltest(df2_1[["TALLA (Centímetros)"]])


alpha = 0.05


columns=df2_1[["TALLA (Centímetros)"]]

for i in columns:
    print ([i])
    a,b= stats.kstest(df2_1[[i]], 'norm')
    print ("Statistics", a, "p-value", b)
    if b < alpha:  
        print("The null hypothesis can be rejected")
    else:
        print("The null hypothesis cannot be rejected")
# Out:
# ['TALLA (Centímetros)']
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-18-7fece7c99813> in <module>
#       9 for i in columns:
#      10     print ([i])
# ---> 11     a,b= stats.kstest(df2_1[[i]], 'norm')
#      12     print ("Statistics", a, "p-value", b)
#      13     if b < alpha:
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py in kstest(rvs, cdf, args, N, alternative, mode)
#    7658     xvals, yvals, cdf = _parse_kstest_args(rvs, cdf, args, N)
#    7659     if cdf:
# -> 7660         return ks_1samp(xvals, cdf, args=args, alternative=alternative,
#    7661                         mode=mode)
#    7662     return ks_2samp(xvals, yvals, alternative=alternative, mode=mode)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py in ks_1samp(x, cdf, args, alternative, mode)
#    7023
#    7024     # alternative == 'two-sided':
# ...

# %%
k2, p = stats.normaltest(df2_1[["TALLA (Centímetros)"]])

# %%
 a,b= stats.kstest(df2_1["TALLA (Centímetros)"], 'norm')

# %%
print ("Statistics", a, "p-value", b)
if b < alpha:  
        print("The null hypothesis can be rejected")
else:
        print("The null hypothesis cannot be rejected")
# Out:
# Statistics 1.0 p-value 0.0
# The null hypothesis can be rejected

# %%
df2_1['TIPO PARTO'].unique()
# Out:
# array(['CESÁREA', 'ESPONTÁNEO', 'INSTRUMENTADO', 'IGNORADO'], dtype=object)

# %%
ax = sns.boxplot( x=df2_1['TIPO PARTO'], y=df2_1["TALLA (Centímetros)"])
ax, test_results = add_stat_annotation(ax, x=df2_1['TIPO PARTO'], y=df2_1["TALLA (Centímetros)"], 
                                     
                                   box_pairs=[('CESÁREA', 'ESPONTÁNEO'), ( 'INSTRUMENTADO', 'IGNORADO'), ('CESÁREA', 'IGNORADO'),('CESÁREA', 'INSTRUMENTADO'),( 'ESPONTÁNEO', 'IGNORADO'),('ESPONTÁNEO', 'INSTRUMENTADO')],
                                   test='Mann-Whitney', text_format='star', loc='outside', verbose=2)
plt.savefig('Talla.png', dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# CESÁREA v.s. ESPONTÁNEO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.736e-144 U_stat=1.400e+08
# INSTRUMENTADO v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.180e+03
# ESPONTÁNEO v.s. INSTRUMENTADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.020e-10 U_stat=7.528e+06
# CESÁREA v.s. INSTRUMENTADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=9.131e-42 U_stat=5.485e+06
# ESPONTÁNEO v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.463e+04
# CESÁREA v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.058e+04

# %%
ax = sns.boxplot( x=df2_1['TIPO PARTO'], y=df2_1["PESO (Gramos)"])
ax, test_results = add_stat_annotation(ax, x=df2_1['TIPO PARTO'], y=df2_1["PESO (Gramos)"], 
                                     
                                   box_pairs=[('CESÁREA', 'ESPONTÁNEO'), ( 'INSTRUMENTADO', 'IGNORADO'), ('CESÁREA', 'IGNORADO'),('CESÁREA', 'INSTRUMENTADO'),( 'ESPONTÁNEO', 'IGNORADO'),('ESPONTÁNEO', 'INSTRUMENTADO')],
                                   test='Mann-Whitney', text_format='star', loc='outside', verbose=2)
plt.savefig('Talla.png', dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# CESÁREA v.s. ESPONTÁNEO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.894e-45 U_stat=1.512e+08
# INSTRUMENTADO v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.016e+03
# ESPONTÁNEO v.s. INSTRUMENTADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.994e-19 U_stat=7.070e+06
# CESÁREA v.s. INSTRUMENTADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.107e-33 U_stat=5.680e+06
# ESPONTÁNEO v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.128e+04
# CESÁREA v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.867e+04

# %%
ax = sns.boxplot( x=df2_1['TIPO PARTO'], y=df2_1["TIEMPO DE GESTACIÓN"])
ax, test_results = add_stat_annotation(ax, x=df2_1['TIPO PARTO'], y=df2_1["TIEMPO DE GESTACIÓN"], 
                                     
                                   box_pairs=[('CESÁREA', 'ESPONTÁNEO'), ( 'INSTRUMENTADO', 'IGNORADO'), ('CESÁREA', 'IGNORADO'),('CESÁREA', 'INSTRUMENTADO'),( 'ESPONTÁNEO', 'IGNORADO'),('ESPONTÁNEO', 'INSTRUMENTADO')],
                                   test='Mann-Whitney', text_format='star', loc='outside', verbose=2)
plt.savefig('Talla.png', dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# CESÁREA v.s. ESPONTÁNEO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.467e-198 U_stat=1.361e+08
# INSTRUMENTADO v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.226e+03
# ESPONTÁNEO v.s. INSTRUMENTADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.363e-15 U_stat=7.311e+06
# CESÁREA v.s. INSTRUMENTADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.156e-61 U_stat=5.088e+06
# ESPONTÁNEO v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.380e+04
# CESÁREA v.s. IGNORADO: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.716e+04
